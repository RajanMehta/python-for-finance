# %%
import numpy as np
import pandas as pd

data = pd.read_csv('CAPM_data.csv', index_col = 'Date')

# %%
sec_returns = np.log( data / data.shift(1) )
sec_returns
# Out:
#                   PG     ^GSPC
# Date
# 2012-01-03       NaN       NaN
# 2012-01-04 -0.000449  0.000188
# 2012-01-05 -0.004201  0.002939
# 2012-01-06 -0.002408 -0.002540
# 2012-01-09  0.004211  0.002259
# 2012-01-10 -0.004663  0.008847
# 2012-01-11 -0.009848  0.000310
# 2012-01-12  0.001977  0.002334
# 2012-01-13  0.000000 -0.004960
# 2012-01-17  0.006815  0.003547
# 2012-01-18 -0.003477  0.011047
# 2012-01-19  0.000757  0.004927
# 2012-01-20  0.002267  0.000669
# 2012-01-23 -0.018746  0.000471
# 2012-01-24 -0.007722 -0.001026
# 2012-01-25  0.007414  0.008642
# 2012-01-26 -0.002774 -0.005771
# 2012-01-27 -0.007746 -0.001594
# 2012-01-30 -0.017097 -0.002525
# 2012-01-31 -0.002693 -0.000457
# 2012-02-01  0.002693  0.008860
# 2012-02-02  0.001739  0.001095
# 2012-02-03 -0.008724  0.014500
# 2012-02-06  0.011720 -0.000424
# 2012-02-07  0.002987  0.002021
# 2012-02-08 -0.000942  0.002158
# 2012-02-09  0.006266  0.001473
# 2012-02-10 -0.002502 -0.006910
# 2012-02-13  0.005464  0.006777
# 2012-02-14  0.003885 -0.000940
# ...              ...       ...
# 2016-11-17 -0.001444  0.004665
# 2016-11-18 -0.012964 -0.002390
# 2016-11-21  0.007775  0.007434
# 2016-11-22  0.001451  0.002163
# 2016-11-23 -0.000967  0.000808
# 2016-11-25  0.009390  0.003907
# 2016-11-28 -0.004684 -0.005268
# 2016-11-29 -0.002169  0.001334
# 2016-11-30 -0.005201 -0.002657
# 2016-12-01 -0.007303 -0.003522
# 2016-12-02  0.006575  0.000397
# 2016-12-05  0.007135  0.005804
# 2016-12-06 -0.000964  0.003405
# 2016-12-07  0.015202  0.013077
# 2016-12-08 -0.008111  0.002157
# 2016-12-09  0.010365  0.005921
# 2016-12-12  0.008968 -0.001138
# 2016-12-13  0.000587  0.006518
# 2016-12-14 -0.009555 -0.008150
# 2016-12-15  0.003668  0.003876
# 2016-12-16  0.000000 -0.001752
# 2016-12-19  0.000354  0.001973
# 2016-12-20 -0.001654  0.003631
# 2016-12-21 -0.003435 -0.002460
# 2016-12-22  0.002252 -0.001865
# 2016-12-23  0.005784  0.001251
# 2016-12-27 -0.004246  0.002246
# 2016-12-28 -0.006284 -0.008392
# 2016-12-29  0.003325 -0.000293
# 2016-12-30 -0.003206 -0.004648
#
# [1258 rows x 2 columns]

# %%
cov = sec_returns.cov() * 250
cov
# Out:
#              PG     ^GSPC
# PG     0.020843  0.010025
# ^GSPC  0.010025  0.016361

# %%
cov_with_market = cov.iloc[0,1]
cov_with_market
# Out:
# 0.010025480950656808

# %%
market_var = sec_returns['^GSPC'].var() * 250
market_var
# Out:
# 0.016360592699269063

# %% [markdown]
# ** Beta: **
# ### $$
# \beta_{pg} = \frac{\sigma_{pg,m}}{\sigma_{m}}
# $$

# %%
PG_beta = cov_with_market / market_var
PG_beta
# Out:
# 0.61278225886674098

# %% [markdown]
# #### Calculate expected return of P&G (CAPM)

# %%
# r_pg = r_f + pg_beta * (r_m - r_f)

PG_er = 0.025 + PG_beta * 0.05
PG_er
# Out:
# 0.055639112943337052

# %% [markdown]
# #### Obtaining Sharpe Ratio

# %%
Sharpe = (PG_er - 0.025)/ (sec_returns['PG'].std()* 250**0.5)
Sharpe
# Out:
# 0.21222619272784843
